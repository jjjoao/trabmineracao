# %% [markdown]
# <a href="https://colab.research.google.com/github/jjjoao/trabmineracao/blob/main/trab_minera%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import kagglehub
import os

caminho = kagglehub.dataset_download('bhavikjikadara/mental-health-dataset')
arquivo = os.listdir(caminho)[0]
df = pd.read_csv(os.path.join(caminho,arquivo))
df.head()
# Out:
#          Timestamp  Gender        Country Occupation self_employed  \
# 0  8/27/2014 11:29  Female  United States  Corporate           NaN
# 1  8/27/2014 11:31  Female  United States  Corporate           NaN
# 2  8/27/2014 11:32  Female  United States  Corporate           NaN
# 3  8/27/2014 11:37  Female  United States  Corporate            No
# 4  8/27/2014 11:43  Female  United States  Corporate            No
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days            Yes             No
# 1            Yes       Yes    1-14 days            Yes             No
# 2            Yes       Yes    1-14 days            Yes             No
# 3            Yes       Yes    1-14 days            Yes             No
# 4            Yes       Yes    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                   Yes      Medium               No            No
# 1                   Yes      Medium               No            No
# 2                   Yes      Medium               No            No
# 3                   Yes      Medium               No            No
# 4                   Yes      Medium               No            No
#
#   Social_Weakness mental_health_interview care_options
# 0             Yes                      No     Not sure
# 1             Yes                      No           No
# 2             Yes                      No          Yes
# 3             Yes                   Maybe          Yes
# 4             Yes                      No          Yes

# %%
from sklearn.preprocessing import StandardScaler

# Criando o scaler e aplicando
scaler = StandardScaler()
#df['age_padronizada'] = scaler.fit_transform(df[['age']])
#round(df['age_padronizada'].describe(), 4)

#df['mental_health_history'].value_counts()
#dummiesg = pd.get_dummies(df['gender'], drop_first=True)
#df = pd.concat([df, dummiesg], axis=1)
#df = df.rename(columns={'Male': 'gender:Male', 'Outro': 'gender:Outro'})

df = df[df['Work_Interest'] != 'Maybe']

dummiesg = pd.get_dummies(df['Gender'], drop_first=True)
df = pd.concat([df, dummiesg], axis=1)

dummiesc = pd.get_dummies(df['Country'], drop_first=True)
df = pd.concat([df, dummiesc], axis=1)

dummieso = pd.get_dummies(df['Occupation'], drop_first=True)
df = pd.concat([df, dummieso], axis=1)
df = df.rename(columns={'Housewife': 'occupation:Housewife', 'Student': 'occupation:Student', 'Corporate': 'occupation:Corporate', 'Others': 'occupation:Others'})

dummiesse = pd.get_dummies(df['self_employed'], drop_first=True)
df = pd.concat([df, dummiesse], axis=1)
df = df.rename(columns={'Yes': 'SelfEmployed'})

dummiesfh = pd.get_dummies(df['family_history'], drop_first=True)
df = pd.concat([df, dummiesfh], axis=1)
df = df.rename(columns={'Yes': 'FamilyHistory'})

dummiest = pd.get_dummies(df['treatment'], drop_first=True)
df = pd.concat([df, dummiest], axis=1)
df = df.rename(columns={'Yes': 'Treatment'})

dummiesdi = pd.get_dummies(df['Days_Indoors'], drop_first=True)
df = pd.concat([df, dummiesdi], axis=1)
df = df.rename(columns={'1-14 days': 'Days_Indoors:1-14', '31-60 days': 'Days_Indoors:31-60', 'Go out Every day': 'Days_Indoors:Go out Every day', 'More than 2 months': 'Days_Indoors:60+', '15-30 days': 'Days_Indoors:15-30' })

dummiesgs = pd.get_dummies(df['Growing_Stress'], drop_first=True)
df = pd.concat([df, dummiesgs], axis=1)
df = df.rename(columns={'Yes': 'Growing_Stress: Yes', 'Maybe': 'Growing_Stress: Maybe', 'No': 'Growing_Stress: No'})

dummiesch = pd.get_dummies(df['Changes_Habits'], drop_first=True)
df = pd.concat([df, dummiesch], axis=1)
df = df.rename(columns={'Yes': 'Changes_Habits: Yes', 'Maybe': 'Changes_Habits: Maybe', 'No': 'Changes_Habits: No'})

dummiesmhh = pd.get_dummies(df['Mental_Health_History'], drop_first=True)
df = pd.concat([df, dummiesmhh], axis=1)
df = df.rename(columns={'Yes': 'Mental_Health_History: Yes', 'Maybe': 'Mental_Health_History: Maybe', 'No': 'Mental_Health_History: No'})

dummiesms = pd.get_dummies(df['Mood_Swings'], drop_first=True)
df = pd.concat([df, dummiesms], axis=1)
df = df.rename(columns={'Medium': 'Mood_Swings: Medium', 'Low': 'Mood_Swings: Low', 'High': 'Mood_Swings: High'})

dummiescs = pd.get_dummies(df['Coping_Struggles'], drop_first=True)
df = pd.concat([df, dummiescs], axis=1)
df = df.rename(columns={'Yes': 'CopingStruggles'})

dummieswi = pd.get_dummies(df['Work_Interest'], drop_first=True)
df = pd.concat([df, dummieswi], axis=1)
df = df.rename(columns={'Yes': 'Work_Interest: Yes', 'Maybe': 'Work_Interest: Maybe', 'No': 'Work_Interest: No'})

dummiessw = pd.get_dummies(df['Social_Weakness'], drop_first=True)
df = pd.concat([df, dummiessw], axis=1)
df = df.rename(columns={'Yes': 'Social_Weakness: Yes', 'Maybe': 'Social_Weakness: Maybe', 'No': 'Social_Weakness: No'})

dummiesmhi = pd.get_dummies(df['mental_health_interview'], drop_first=True)
df = pd.concat([df, dummiesmhi], axis=1)
df = df.rename(columns={'Yes': 'mental_health_interview: Yes', 'Maybe': 'mental_health_interview: Maybe', 'No': 'mental_health_interview: No'})

dummiesmhi = pd.get_dummies(df['care_options'], drop_first=True)
df = pd.concat([df, dummiesmhi], axis=1)
df = df.rename(columns={'Yes': 'care_options: Yes', 'Not sure': 'care_options: Not sure', 'No': 'care_options: No'})

#df['care_options'].value_counts()
df.head()
# Out:
#          Timestamp  Gender        Country Occupation self_employed  \
# 0  8/27/2014 11:29  Female  United States  Corporate           NaN
# 1  8/27/2014 11:31  Female  United States  Corporate           NaN
# 2  8/27/2014 11:32  Female  United States  Corporate           NaN
# 3  8/27/2014 11:37  Female  United States  Corporate            No
# 4  8/27/2014 11:43  Female  United States  Corporate            No
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  ...  \
# 0             No       Yes    1-14 days            Yes             No  ...
# 1            Yes       Yes    1-14 days            Yes             No  ...
# 2            Yes       Yes    1-14 days            Yes             No  ...
# 3            Yes       Yes    1-14 days            Yes             No  ...
# 4            Yes       Yes    1-14 days            Yes             No  ...
#
#   Mood_Swings: Low Mood_Swings: Medium CopingStruggles Work_Interest: Yes  \
# 0            False                True           False              False
# 1            False                True           False              False
# 2            False                True           False              False
# 3            False                True           False              False
# 4            False                True           False              False
#
#   Social_Weakness: No Social_Weakness: Yes mental_health_interview: No  \
# 0               False                 True                        True
# 1               False                 True                        True
# 2               False                 True                        True
# 3               False                 True                       False
# 4               False                 True                        True
#
#    mental_health_interview: Yes  care_options: Not sure  care_options: Yes
# 0                         False                    True              False
# 1                         False                   False              False
# 2                         False                   False               True
# 3                         False                   False               True
# 4                         False                   False               True
#
# [5 rows x 79 columns]

# %%
novo_df = df.drop(columns=['Timestamp', 'Gender', 'Country', 'Occupation', 'self_employed', 'family_history', 'treatment', 'Days_Indoors', 'Growing_Stress', 'Changes_Habits', 'Mental_Health_History', 'Mood_Swings', 'Coping_Struggles', 'Work_Interest', 'Social_Weakness', 'mental_health_interview', 'care_options'])

novo_df.head()
# Out:
#     Male  Belgium  Bosnia and Herzegovina  Brazil  Canada  Colombia  \
# 0  False    False                   False   False   False     False
# 1  False    False                   False   False   False     False
# 2  False    False                   False   False   False     False
# 3  False    False                   False   False   False     False
# 4  False    False                   False   False   False     False
#
#    Costa Rica  Croatia  Czech Republic  Denmark  ...  Mood_Swings: Low  \
# 0       False    False           False    False  ...             False
# 1       False    False           False    False  ...             False
# 2       False    False           False    False  ...             False
# 3       False    False           False    False  ...             False
# 4       False    False           False    False  ...             False
#
#    Mood_Swings: Medium  CopingStruggles  Work_Interest: Yes  \
# 0                 True            False               False
# 1                 True            False               False
# 2                 True            False               False
# 3                 True            False               False
# 4                 True            False               False
#
#    Social_Weakness: No  Social_Weakness: Yes  mental_health_interview: No  \
# 0                False                  True                         True
# 1                False                  True                         True
# 2                False                  True                         True
# 3                False                  True                        False
# 4                False                  True                         True
#
#    mental_health_interview: Yes  care_options: Not sure  care_options: Yes
# 0                         False                    True              False
# 1                         False                   False              False
# 2                         False                   False               True
# 3                         False                   False               True
# 4                         False                   False               True
#
# [5 rows x 62 columns]

# %%
# !pip install pycaret -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.1/486.1 kB 31.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 9.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 85.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 22.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 100.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 89.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 102.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 53.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.6/200.6 kB 15.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 90.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 12.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 104.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 66.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.1/130.1 kB 11.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 60.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.1.4 which is incompatible.
# mizani 0.13.5 requires pandas>=2.2.0, but you have pandas 2.1.4 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.11.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.5 which is incompatible.
# plotnine 0.14.5 requires pandas>=2.2.0, but you have pandas 2.1.4 which is incompatible.

# %%
from pycaret.classification import *
setup(data = novo_df, target = 'Work_Interest: Yes')
# Out:
# <style type="text/css">
# #T_43ca2_row7_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_43ca2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_43ca2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_43ca2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43ca2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_43ca2_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_43ca2_row0_col1" class="data row0 col1" >1485</td>
#     </tr>
#     <tr>
#       <th id="T_43ca2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_43ca2_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_43ca2_row1_col1" class="data row1 col1" >Work_Interest: Yes</td>
#     </tr>
#     <tr>
#       <th id="T_43ca2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_43ca2_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_43ca2_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_43ca2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_43ca2_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_43ca2_row3_col1" class="data row3 col1" >(191179, 62)</td>
#     </tr>
#     <tr>
#       <th id="T_43ca2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_43ca2_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_43ca2_row4_col1" class="data row4 col1" >(191179, 62)</td>
#     </tr>
#     <tr>
#       <th id="T_43ca2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_43ca2_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_43ca2_row5_col1" class="data row5 col1" >(133825, 62)</td>
#     </tr>
#     <tr>
#       <th id="T_43ca2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_43ca2_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_43ca2_row6_col1" class="data row6 col1" >(57354, 62)</td>
#     </tr>
#     <tr>
#       <th id="T_43ca2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_43ca2_row7_col0" class="data row7 col0" >Preprocess</td>
#       <td id="T_43ca2_row7_col1" class="data row7 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_43ca2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_43ca2_row8_col0" class="data row8 col0" >Imputation type</td>
#       <td id="T_43ca2_row8_col1" class="data row8 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_43ca2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_43ca2_row9_col0" class="data row9 col0" >Numeric imputation</td>
#       <td id="T_43ca2_row9_col1" class="data row9 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_43ca2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_43ca2_row10_col0" class="data row10 col0" >Categorical imputation</td>
#       <td id="T_43ca2_row10_col1" class="data row10 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_43ca2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_43ca2_row11_col0" class="data row11 col0" >Fold Generator</td>
#       <td id="T_43ca2_row11_col1" class="data row11 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_43ca2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_43ca2_row12_col0" class="data row12 col0" >Fold Number</td>
#       <td id="T_43ca2_row12_col1" class="data row12 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_43ca2_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_43ca2_row13_col0" class="data row13 col0" >CPU Jobs</td>
#       <td id="T_43ca2_row13_col1" class="data row13 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_43ca2_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_43ca2_row14_col0" class="data row14 col0" >Use GPU</td>
#       <td id="T_43ca2_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_43ca2_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_43ca2_row15_col0" class="data row15 col0" >Log Experiment</td>
#       <td id="T_43ca2_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_43ca2_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_43ca2_row16_col0" class="data row16 col0" >Experiment Name</td>
#       <td id="T_43ca2_row16_col1" class="data row16 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_43ca2_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_43ca2_row17_col0" class="data row17 col0" >USI</td>
#       <td id="T_43ca2_row17_col1" class="data row17 col1" >ef5b</td>
#     </tr>
#   </tbody>
# </table>

# %%
modelos = compare_models( )
# Out:
# <style type="text/css">
# #T_372bb th {
#   text-align: left;
# }
# #T_372bb_row0_col0, #T_372bb_row0_col4, #T_372bb_row0_col6, #T_372bb_row0_col7, #T_372bb_row1_col0, #T_372bb_row1_col4, #T_372bb_row2_col0, #T_372bb_row2_col1, #T_372bb_row2_col2, #T_372bb_row2_col3, #T_372bb_row2_col5, #T_372bb_row2_col6, #T_372bb_row2_col7, #T_372bb_row3_col0, #T_372bb_row3_col1, #T_372bb_row3_col2, #T_372bb_row3_col3, #T_372bb_row3_col5, #T_372bb_row3_col6, #T_372bb_row3_col7, #T_372bb_row4_col0, #T_372bb_row4_col1, #T_372bb_row4_col2, #T_372bb_row4_col3, #T_372bb_row4_col4, #T_372bb_row4_col5, #T_372bb_row4_col6, #T_372bb_row4_col7, #T_372bb_row5_col0, #T_372bb_row5_col1, #T_372bb_row5_col2, #T_372bb_row5_col3, #T_372bb_row5_col4, #T_372bb_row5_col5, #T_372bb_row5_col6, #T_372bb_row5_col7, #T_372bb_row6_col0, #T_372bb_row6_col1, #T_372bb_row6_col2, #T_372bb_row6_col3, #T_372bb_row6_col4, #T_372bb_row6_col5, #T_372bb_row6_col6, #T_372bb_row6_col7, #T_372bb_row7_col0, #T_372bb_row7_col1, #T_372bb_row7_col2, #T_372bb_row7_col3, #T_372bb_row7_col4, #T_372bb_row7_col5, #T_372bb_row7_col6, #T_372bb_row7_col7, #T_372bb_row8_col0, #T_372bb_row8_col1, #T_372bb_row8_col2, #T_372bb_row8_col3, #T_372bb_row8_col4, #T_372bb_row8_col5, #T_372bb_row8_col6, #T_372bb_row8_col7, #T_372bb_row9_col0, #T_372bb_row9_col1, #T_372bb_row9_col2, #T_372bb_row9_col3, #T_372bb_row9_col4, #T_372bb_row9_col5, #T_372bb_row9_col6, #T_372bb_row9_col7, #T_372bb_row10_col0, #T_372bb_row10_col1, #T_372bb_row10_col2, #T_372bb_row10_col3, #T_372bb_row10_col4, #T_372bb_row10_col5, #T_372bb_row10_col6, #T_372bb_row10_col7, #T_372bb_row11_col0, #T_372bb_row11_col1, #T_372bb_row11_col2, #T_372bb_row11_col3, #T_372bb_row11_col4, #T_372bb_row11_col5, #T_372bb_row11_col6, #T_372bb_row11_col7, #T_372bb_row12_col0, #T_372bb_row12_col1, #T_372bb_row12_col2, #T_372bb_row12_col3, #T_372bb_row12_col4, #T_372bb_row12_col5, #T_372bb_row12_col6, #T_372bb_row12_col7, #T_372bb_row13_col0, #T_372bb_row13_col1, #T_372bb_row13_col2, #T_372bb_row13_col3, #T_372bb_row13_col4, #T_372bb_row13_col5, #T_372bb_row13_col6, #T_372bb_row13_col7, #T_372bb_row14_col0, #T_372bb_row14_col1, #T_372bb_row14_col2, #T_372bb_row14_col3, #T_372bb_row14_col4, #T_372bb_row14_col5, #T_372bb_row14_col6, #T_372bb_row14_col7 {
#   text-align: left;
# }
# #T_372bb_row0_col1, #T_372bb_row0_col2, #T_372bb_row0_col3, #T_372bb_row0_col5, #T_372bb_row1_col1, #T_372bb_row1_col2, #T_372bb_row1_col3, #T_372bb_row1_col5, #T_372bb_row1_col6, #T_372bb_row1_col7, #T_372bb_row2_col4, #T_372bb_row3_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_372bb_row0_col8, #T_372bb_row1_col8, #T_372bb_row2_col8, #T_372bb_row3_col8, #T_372bb_row4_col8, #T_372bb_row5_col8, #T_372bb_row6_col8, #T_372bb_row7_col8, #T_372bb_row8_col8, #T_372bb_row9_col8, #T_372bb_row10_col8, #T_372bb_row11_col8, #T_372bb_row12_col8, #T_372bb_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_372bb_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_372bb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_372bb_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_372bb_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_372bb_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_372bb_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_372bb_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_372bb_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_372bb_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_372bb_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_372bb_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_372bb_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_372bb_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_372bb_row0_col1" class="data row0 col1" >0.9992</td>
#       <td id="T_372bb_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_372bb_row0_col3" class="data row0 col3" >0.9990</td>
#       <td id="T_372bb_row0_col4" class="data row0 col4" >0.9991</td>
#       <td id="T_372bb_row0_col5" class="data row0 col5" >0.9991</td>
#       <td id="T_372bb_row0_col6" class="data row0 col6" >0.9983</td>
#       <td id="T_372bb_row0_col7" class="data row0 col7" >0.9983</td>
#       <td id="T_372bb_row0_col8" class="data row0 col8" >9.8100</td>
#     </tr>
#     <tr>
#       <th id="T_372bb_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_372bb_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_372bb_row1_col1" class="data row1 col1" >0.9992</td>
#       <td id="T_372bb_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T
level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_23098_row7_col0" class="data row7 col0" >0.9993</td>
#       <td id="T_23098_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_23098_row7_col2" class="data row7 col2" >0.9992</td>
#       <td id="T_23098_row7_col3" class="data row7 col3" >0.9992</td>
#       <td id="T_23098_row7_col4" class="data row7 col4" >0.9992</td>
#       <td id="T_23098_row7_col5" class="data row7 col5" >0.9985</td>
#       <td id="T_23098_row7_col6" class="data row7 col6" >0.9985</td>
#     </tr>
#     <tr>
#       <th id="T_23098_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_23098_row8_col0" class="data row8 col0" >0.9992</td>
#       <td id="T_23098_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_23098_row8_col2" class="data row8 col2" >0.9998</td>
#       <td id="T_23098_row8_col3" class="data row8 col3" >0.9983</td>
#       <td id="T_23098_row8_col4" class="data row8 col4" >0.9991</td>
#       <td id="T_23098_row8_col5" class="data row8 col5" >0.9983</td>
#       <td id="T_23098_row8_col6" class="data row8 col6" >0.9983</td>
#     </tr>
#     <tr>
#       <th id="T_23098_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_23098_row9_col0" class="data row9 col0" >0.9990</td>
#       <td id="T_23098_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_23098_row9_col2" class="data row9 col2" >0.9988</td>
#       <td id="T_23098_row9_col3" class="data row9 col3" >0.9990</td>
#       <td id="T_23098_row9_col4" class="data row9 col4" >0.9989</td>
#       <td id="T_23098_row9_col5" class="data row9 col5" >0.9980</td>
#       <td id="T_23098_row9_col6" class="data row9 col6" >0.9980</td>
#     </tr>
#     <tr>
#       <th id="T_23098_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_23098_row10_col0" class="data row10 col0" >0.9992</td>
#       <td id="T_23098_row10_col1" class="data row10 col1" >1.0000</td>
#       <td id="T_23098_row10_col2" class="data row10 col2" >0.9990</td>
#       <td id="T_23098_row10_col3" class="data row10 col3" >0.9991</td>
#       <td id="T_23098_row10_col4" class="data row10 col4" >0.9991</td>
#       <td id="T_23098_row10_col5" class="data row10 col5" >0.9983</td>
#       <td id="T_23098_row10_col6" class="data row10 col6" >0.9983</td>
#     </tr>
#     <tr>
#       <th id="T_23098_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_23098_row11_col0" class="data row11 col0" >0.0002</td>
#       <td id="T_23098_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_23098_row11_col2" class="data row11 col2" >0.0005</td>
#       <td id="T_23098_row11_col3" class="data row11 col3" >0.0004</td>
#       <td id="
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
rftunado = tune_model(rf)
# Out:
# <style type="text/css">
# #T_b2952_row10_col0, #T_b2952_row10_col1, #T_b2952_row10_col2, #T_b2952_row10_col3, #T_b2952_row10_col4, #T_b2952_row10_col5, #T_b2952_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_b2952" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b2952_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_b2952_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_b2952_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_b2952_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_b2952_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_b2952_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_b2952_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2952_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b2952_row0_col0" class="data row0 col0" >0.9316</td>
#       <td id="T_b2952_row0_col1" class="data row0 col1" >0.9902</td>
#       <td id="T_b2952_row0_col2" class="data row0 col2" >0.9802</td>
#       <td id="T_b2952_row0_col3" class="data row0 col3" >0.8802</td>
#       <td id="T_b2952_row0_col4" class="data row0 col4" >0.9275</td>
#       <td id="T_b2952_row0_col5" class="data row0 col5" >0.8632</td>
#       <td id="T_b2952_row0_col6" class="data row0 col6" >0.8677</td>
#     </tr>
#     <tr>
#       <th id="T_b2952_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_
level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b2952_row7_col0" class="data row7 col0" >0.9310</td>
#       <td id="T_b2952_row7_col1" class="data row7 col1" >0.9901</td>
#       <td id="T_b2952_row7_col2" class="data row7 col2" >0.9838</td>
#       <td id="T_b2952_row7_col3" class="data row7 col3" >0.8766</td>
#       <td id="T_b2952_row7_col4" class="data row7 col4" >0.9271</td>
#       <td id="T_b2952_row7_col5" class="data row7 col5" >0.8619</td>
#       <td id="T_b2952_row7_col6" class="data row7 col6" >0.8671</td>
#     </tr>
#     <tr>
#       <th id="T_b2952_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b2952_row8_col0" class="data row8 col0" >0.9351</td>
#       <td id="T_b2952_row8_col1" class="data row8 col1" >0.9908</td>
#       <td id="T_b2952_row8_col2" class="data row8 col2" >0.9784</td>
#       <td id="T_b2952_row8_col3" class="data row8 col3" >0.8876</td>
#       <td id="T_b2952_row8_col4" class="data row8 col4" >0.9308</td>
#       <td id="T_b2952_row8_col5" class="data row8 col5" >0.8699</td>
#       <td id="T_b2952_row8_col6" class="data row8 col6" >0.8736</td>
#     </tr>
#     <tr>
#       <th id="T_b2952_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b2952_row9_col0" class="data row9 col0" >0.9477</td>
#       <td id="T_b2952_row9_col1" class="data row9 col1" >0.9941</td>
#       <td id="T_b2952_row9_col2" class="data row9 col2" >0.9799</td>
#       <td id="T_b2952_row9_col3" class="data row9 col3" >0.9098</td>
#       <td id="T_b2952_row9_col4" class="data row9 col4" >0.9436</td>
#       <td id="T_b2952_row9_col5" class="data row9 col5" >0.8949</td>
#       <td id="T_b2952_row9_col6" class="data row9 col6" >0.8971</td>
#     </tr>
#     <tr>
#       <th id="T_b2952_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_b2952_row10_col0" class="data row10 col0" >0.9372</td>
#       <td id="T_b2952_row10_col1" class="data row10 col1" >0.9912</td>
#       <td id="T_b2952_row10_col2" class="data row10 col2" >0.9800</td>
#       <td id="T_b2952_row10_col3" class="data row10 col3" >0.8906</td>
#       <td id="T_b2952_row10_col4" class="data row10 col4" >0.9331</td>
#       <td id="T_b2952_row10_col5" class="data row10 col5" >0.8742</td>
#       <td id="T_b2952_row10_col6" class="data row10 col6" >0.8778</td>
#     </tr>
#     <tr>
#       <th id="T_b2952_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_b2952_row11_col0" class="data row11 col0" >0.0066</td>
#       <td id="T_b2952_row11_col1" class="data row11 col1" >0.0016</td>
#       <td id="T_b2952_row11_col2" class="data row11 col2" >0.0029</td>
#       <td id="T_b2952_row11_col3" class="data row11 col3" >0.0128</td>
#       <td id="
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
xgboost = create_model('xgboost')
# Out:
# <style type="text/css">
# #T_f06d3_row10_col0, #T_f06d3_row10_col1, #T_f06d3_row10_col2, #T_f06d3_row10_col3, #T_f06d3_row10_col4, #T_f06d3_row10_col5, #T_f06d3_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_f06d3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f06d3_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_f06d3_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_f06d3_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_f06d3_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_f06d3_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_f06d3_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_f06d3_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f06d3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f06d3_row0_col0" class="data row0 col0" >0.9994</td>
#       <td id="T_f06d3_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T
row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_f06d3_row6_col2" class="data row6 col2" >0.9987</td>
#       <td id="T_f06d3_row6_col3" class="data row6 col3" >0.9997</td>
#       <td id="T_f06d3_row6_col4" class="data row6 col4" >0.9992</td>
#       <td id="T_f06d3_row6_col5" class="data row6 col5" >0.9985</td>
#       <td id="T_f06d3_row6_col6" class="data row6 col6" >0.9985</td>
#     </tr>
#     <tr>
#       <th id="T_f06d3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f06d3_row7_col0" class="data row7 col0" >0.9993</td>
#       <td id="T_f06d3_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_f06d3_row7_col2" class="data row7 col2" >0.9993</td>
#       <td id="T_f06d3_row7_col3" class="data row7 col3" >0.9990</td>
#       <td id="T_f06d3_row7_col4" class="data row7 col4" >0.9992</td>
#       <td id="T_f06d3_row7_col5" class="data row7 col5" >0.9985</td>
#       <td id="T_f06d3_row7_col6" class="data row7 col6" >0.9985</td>
#     </tr>
#     <tr>
#       <th id="T_f06d3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f06d3_row8_col0" class="data row8 col0" >0.9993</td>
#       <td id="T_f06d3_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_f06d3_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_f06d3_row8_col3" class="data row8 col3" >0.9985</td>
#       <td id="T_f06d3_row8_col4" class="data row8 col4" >0.9992</td>
#       <td id="T_f06d3_row8_col5" class="data row8 col5" >0.9986</td>
#       <td id="T_f06d3_row8_col6" class="data row8 col6" >0.9986</td>
#     </tr>
#     <tr>
#       <th id="T_f06d3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f06d3_row9_col0" class="data row9 col0" >0.9991</td>
#       <td id="T_f06d3_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_f06d3_row9_col2" class="data row9 col2" >0.9988</td>
#       <td id="T_f06d3_row9_col3" class="data row9 col3" >0.9992</td>
#       <td id="T_f06d3_row9_col4" class="data row9 col4" >0.9990</td>
#       <td id="T_f06d3_row9_col5" class="data row9 col5" >0.9982</td>
#       <td id="T_f06d3_row9_col6" class="data row9 col6" >0.9982</td>
#     </tr>
#     <tr>
#       <th id="T_f06d3_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_f06d3_row10_col0" class="data row10 col0" >0.9992</td>
#       <td id="T_f06d3_row10_col1" class="data row10 col1" >1.0000</td>
#       <td id="T_f06d3_row10_col2" class="data row10 col2" >0.9990</td>
#       <td id="T_f06d3_row10_col3" class="data row10 col3" >0.9991</td>
#       <td id="T_f06d3_row10_col4" class="data row10 col4" >0.9991</td>
#       <td id="T_f06d3_row10_col5" class="data row10 col5" >0.9984</td>
#       <td id="T_f06d3_row10_col6" class="data row10 col6" >0.9984</td>
#     </tr>
#     <tr>
#       <th id="T_f06d3_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_f06d3_row11_col0" class="data row11 col0" >0.0002</td>
#       <td id="T_f06d3_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_f06d3_row11_col2" class="data row11 col2" >0.0007</td>
#       <td id="T_f06d3_row11_col3" class="data row11 col3" >0.0006</td>
#       <td id="
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
xgtunado = tune_model(xgboost)
# Out:
# <style type="text/css">
# #T_75def_row10_col0, #T_75def_row10_col1, #T_75def_row10_col2, #T_75def_row10_col3, #T_75def_row10_col4, #T_75def_row10_col5, #T_75def_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_75def" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75def_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_75def_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_75def_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_75def_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_75def_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_75def_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_75def_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75def_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_75def_row0_col0" class="data row0 col0" >0.9995</td>
#       <td id="T_75def_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_75def_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_75def_row0_col3" class="data row0 col3" >0.9988</td>
#       <td id="T_75def_row0_col4" class="data row0 col4" >0.9994</td>
#       <td id="T_75def_row0_col5" class="data row0 col5" >0.9989</td>
#       <td id="T_75def_row0_col6" class="data row0 col6" >0.9989</td>
#     </tr>
#     <tr>
#       <th id="T_75def_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_75def_row1_col0" class="data row1 col0" >0.9992</td>
#       <td id="T_75def_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_75def_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_75def_row1_col3" class="data row1 col3" >0.9982</td>
#       <td id="T_75def_row1_col4" class="data row1 col4" >0.9991</td>
#       <td id="T_75def_row1_col5" class="data row1 col5" >0.9983</td>
#       <td id="T_75def_row1_col6" class="data row1 col6" >0.9983</td>
#     </tr>
#     <tr>
#       <th id="T_75def_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_75def_row2_col0" class="data row2 col0" >0.9997</td>
#       <td id="T_75def_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_75def_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_75def_row2_col3" class="data row2 col3" >0.9993</td>
#       <td id="T_75def_row2_col4" class="data row2 col4" >0.9997</td>
#       <td id="T_75def_row2_col5" class="data row2 col5" >0.9994</td>
#       <td id="T_75def_row2_col6" class="data row2 col6" >0.9994</td>
#     </tr>
#     <tr>
#       <th id="T_75def_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_75def_row3_col0" class="data row3 col0" >0.9990</td>
#       <td id="T_75def_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_75def_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_75def_row3_col3" class="data row3 col3" >0.9978</td>
#       <td id="T_75def_row3_col4" class="data row3 col4" >0.9989</td>
#       <td id="T_75def_row3_col5" class="data row3 col5" >0.9980</td>
#       <td id="T_75def_row3_col6" class="data row3 col6" >0.9980</td>
#     </tr>
#     <tr>
#       <th id="T_75def_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_75def_row4_col0" class="data row4 col0" >0.9996</td>
#       <td id="T_75def_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_75def_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_75def_row4_col3" class="data row4 col3" >0.9990</td>
#       <td id="T_75def_row4_col4" class="data row4 col4" >0.9995</td>
#       <td id="T_75def_row4_col5" class="data row4 col5" >0.9991</td>
#       <td id="T_75def_row4_col6" class="data row4 col6" >0.9991</td>
#     </tr>
#     <tr>
#       <th id="T_75def_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_75def_row5_col0" class="data row5 col0" >0.9994</td>
#       <td id="T_75def_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_75def_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_75def_row5_col3" class="data row5 col3" >0.9987</td>
#       <td id="T_75def_row5_col4" class="data row5 col4" >0.9993</td>
#       <td id="T_75def_row5_col5" class="data row5 col5" >0.9988</td>
#       <td id="T_75def_row5_col6" class="data row5 col6" >0.9988</td>
#     </tr>
#     <tr>
#       <th id="T_75def_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_75def_row6_col0" class="data row6 col0" >0.9993</td>
#       <td id="T_75def_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_75def_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_75def_row6_col3" class="data row6 col3" >0.9983</td>
#       <td id="T_75def_row6_col4" class="data row6 col4" >0.9992</td>
#       <td id="T_75def_row6_col5" class="data row6 col5" >0.9985</td>
#       <td id="T_75def_row6_col6" class="data row6 col6" >0.9985</td>
#     </tr>
#     <tr>
#       <th id="T_75def_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_75def_row7_col0" class="data row7 col0" >0.9995</td>
#       <td id="T_75def_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_75def_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_75def_row7_col3" class="data row7 col3" >0.9988</td>
#       <td id="T_75def_row7_col4" class="data row7 col4" >0.9994</td>
#       <td id="T_75def_row7_col5" class="data row7 col5" >0.9989</td>
#       <td id="T_75def_row7_col6" class="data row7 col6" >0.9989</td>
#     </tr>
#     <tr>
#       <th id="T_75def_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_75def_row8_col0" class="data row8 col0" >0.9991</td>
#       <td id="T_75def_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_75def_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_75def_row8_col3" class="data row8 col3" >0.9980</td>
#       <td id="T_75def_row8_col4" class="data row8 col4" >0.9990</td>
#       <td id="T_75def_row8_col5" class="data row8 col5" >0.9982</td>
#       <td id="T_75def_row8_col6" class="data row8 col6" >0.9982</td>
#     </tr>
#     <tr>
#       <th id="T_75def_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_75def_row9_col0" class="data row9 col0" >0.9993</td>
#       <td id="T_75def_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_75def_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_75def_row9_col3" class="data row9 col3" >0.9983</td>
#       <td id="T_75def_row9_col4" class="data row9 col4" >0.9992</td>
#       <td id="T_75def_row9_col5" class="data row9 col5" >0.9985</td>
#       <td id="T_75def_row9_col6" class="data row9 col6" >0.9985</td>
#     </tr>
#     <tr>
#       <th id="T_75def_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_75def_row10_col0" class="data row10 col0" >0.9993</td>
#       <td id="T_75def_row10_col1" class="data row10 col1" >1.0000</td>
#       <td id="T_75def_row10_col2" class="data row10 col2" >1.0000</td>
#       <td id="T_75def_row10_col3" class="data row10 col3" >0.9985</td>
#       <td id="T_75def_row10_col4" class="data row10 col4" >0.9993</td>
#       <td id="T_75def_row10_col5" class="data row10 col5" >0.9987</td>
#       <td id="T_75def_row10_col6" class="data row10 col6" >0.9987</td>
#     </tr>
#     <tr>
#       <th id="T_75def_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_75def_row11_col0" class="data row11 col0" >0.0002</td>
#       <td id="T_75def_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_75def_row11_col2" class="data row11 col2" >0.0000</td>
#       <td id="T_75def_row11_col3" class="data row11 col3" >0.0005</td>
#       <td id="
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
combinado = blend_models([rftunado, xgtunado])
# Out:
# <style type="text/css">
# #T_74e33_row10_col0, #T_74e33_row10_col1, #T_74e33_row10_col2, #T_74e33_row10_col3, #T_74e33_row10_col4, #T_74e33_row10_col5, #T_74e33_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_74e33" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74e33_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_74e33_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_74e33_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_74e33_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_74e33_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_74e33_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_74e33_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74e33_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_74e33_row0_col0" class="data row0 col0" >0.9994</td>
#       <td id="T_74e33_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_74e33_row0_col2" class="data row0 col2" >0.9997</td>
#       <td id="T_74e33_row0_col3" class="data row0 col3" >0.9990</td>
#       <td id="T_74e33_row0_col4" class="data row0 col4" >0.9993</td>
#       <td id="T_74e33_row0_col5" class="data row0 col5" >0.9988</td>
#       <td id="T_74e33_row0_col6" class="data row0 col6" >0.9988</td>
#     </tr>
#     <tr>
#       <th id="T_74e33_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_74e33_row1_col0" class="data row1 col0" >0.9990</td>
#       <td id="T_74e33_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_74e33_row1_col2" class="data row1 col2" >0.9997</td>
#       <td id="T_74e33_row1_col3" class="data row1 col3" >0.9982</td>
#       <td id="T_74e33_row1_col4" class="data row1 col4" >0.9989</td>
#       <td id="T_74e33_row1_col5" class="data row1 col5" >0.9980</td>
#       <td id="T_74e33_row1_col6" class="data row1 col6" >0.9980</td>
#     </tr>
#     <tr>
#       <th id="T_74e33_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_74e33_row2_col0" class="data row2 col0" >0.9996</td>
#       <td id="T_74e33_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_74e33_row2_col2" class="data row2 col2" >0.9998</td>
#       <td id="T_74e33_row2_col3" class="data row2 col3" >0.9993</td>
#       <td id="T_74e33_row2_col4" class="data row2 col4" >0.9996</td>
#       <td id="T_74e33_row2_col5" class="data row2 col5" >0.9992</td>
#       <td id="T_74e33_row2_col6" class="data row2 col6" >0.9992</td>
#     </tr>
#     <tr>
#       <th id="T_74e33_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T
row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_74e33_row9_col2" class="data row9 col2" >0.9998</td>
#       <td id="T_74e33_row9_col3" class="data row9 col3" >0.9983</td>
#       <td id="T_74e33_row9_col4" class="data row9 col4" >0.9991</td>
#       <td id="T_74e33_row9_col5" class="data row9 col5" >0.9983</td>
#       <td id="T_74e33_row9_col6" class="data row9 col6" >0.9983</td>
#     </tr>
#     <tr>
#       <th id="T_74e33_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_74e33_row10_col0" class="data row10 col0" >0.9993</td>
#       <td id="T_74e33_row10_col1" class="data row10 col1" >1.0000</td>
#       <td id="T_74e33_row10_col2" class="data row10 col2" >0.9999</td>
#       <td id="T_74e33_row10_col3" class="data row10 col3" >0.9985</td>
#       <td id="T_74e33_row10_col4" class="data row10 col4" >0.9992</td>
#       <td id="T_74e33_row10_col5" class="data row10 col5" >0.9986</td>
#       <td id="T_74e33_row10_col6" class="data row10 col6" >0.9986</td>
#     </tr>
#     <tr>
#       <th id="T_74e33_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_74e33_row11_col0" class="data row11 col0" >0.0002</td>
#       <td id="T_74e33_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_74e33_row11_col2" class="data row11 col2" >0.0001</td>
#       <td id="T_74e33_row11_col3" class="data row11 col3" >0.0005</td>
#       <td id="
# Processing:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
evaluate_model(combinado)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
x = predict_model(combinado)
# Out:
# <style type="text/css">
# </style>
# <table id="T_90cc8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90cc8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_90cc8_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_90cc8_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_90cc8_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_90cc8_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_90cc8_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_90cc8_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_90cc8_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90cc8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_90cc8_row0_col0" class="data row0 col0" >Voting Classifier</td>
#       <td id="T_90cc8_row0_col1" class="data row0 col1" >0.9994</td>
#       <td id="T_90cc8_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_90cc8_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_90cc8_row0_col4" class="data row0 col4" >0.9987</td>
#       <td id="T_90cc8_row0_col5" class="data row0 col5" >0.9994</td>
#       <td id="T_90cc8_row0_col6" class="data row0 col6" >0.9988</td>
#       <td id="T_90cc8_row0_col7" class="data row0 col7" >0.9988</td>
#     </tr>
#   </tbody>
# </table>

# %%
modelo_final = finalize_model(combinado)

# %%
modelo_final
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None, include=[],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
#                                                               strategy='mean'))),
#                 ('categorical_imputer',
#                  TransformerWrapper(exclude=None, include=[],
#                                     transformer=SimpleImputer(add_indicator...
#                                                              max_bin=None,
#                                                              max_cat_threshold=None,
#                                                              max_cat_to_onehot=None,
#                                                              max_delta_step=None,
#                                                              max_depth=6,
#                                                              max_leaves=None,
#                                                              min_child_weight=4,
#                                                              missing=nan,
#                                                              monotone_constraints=None,
#                                                              multi_strategy=None,
#                                                              n_estimators=220,
#                                                              n_jobs=-1,
#                                                              num_parallel_tree=None,
#                                                              objective='binary:logistic', ...))],
#                                   flatten_transform=True, n_jobs=-1,
#                                   verbose=False, voting='soft',
#                                   weights=None))],
#          verbose=False)

# %%
save_model(modelo_final, 'modelo_final')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None, include=[],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean'))),
#                  ('categorical_imputer',
#                   TransformerWrapper(exclude=None, include=[],
#                                      transformer=SimpleImputer(add_indicator...
#                                                               max_bin=None,
#                                                               max_cat_threshold=None,
#                                                               max_cat_to_onehot=None,
#                                                               max_delta_step=None,
#                                                               max_depth=6,
#                                                               max_leaves=None,
#                                                               min_child_weight=4,
#                                                               missing=nan,
#                                                               monotone_constraints=None,
#                                                               multi_strategy=None,
#                                                               n_estimators=220,
#                                                               n_jobs=-1,
#                                                               num_parallel_tree=None,
#                                                               objective='binary:logistic', ...))],
#                                    flatten_transform=True, n_jobs=-1,
#                                    verbose=False, voting='soft',
#                                    weights=None))],
#           verbose=False),
#  'modelo_final.pkl')
